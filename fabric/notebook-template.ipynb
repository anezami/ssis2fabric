# %% [markdown]
# # ssis2fabric SparkSQL starter
#
# Dylan will populate this notebook with migrated SparkSQL logic.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

# %%
workspace_name = 'ws-ssis2fabric-demo'
lakehouse_name = 'lh_ssis_demo'
lakehouse_path = f'abfss://{workspace_name}@onelake.dfs.fabric.microsoft.com/{lakehouse_name}.Lakehouse'
print(lakehouse_path)

# %%
# Replace dbo_sample_delta_table with the migrated Delta table name.
sample_df = spark.sql('SELECT * FROM dbo_sample_delta_table LIMIT 10')
display(sample_df)
